# %%
print("Hello from Python cell")

# %% [markdown]
# **Notes:** Open this file in VS Code and run cells with the Run Cell (▶) buttons, or run `jupyter notebook` / `jupyter lab`. If packages are missing, run `%pip install <package>`.
